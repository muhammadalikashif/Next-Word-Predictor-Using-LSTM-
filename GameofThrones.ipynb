a. Multiple stories: The show follows a large number of individuals and their individual adventures, with the storylines frequently intersecting and diverging throughout the course of the show. Because of this structure, it is possible to conduct an in-depth and varied investigation of the world of Westeros and the people who live there.

a. Time jumps: In order to advance the plot, Game of Thrones frequently skips months or even years between seasons. This is done in order to drive the story forward. This method not only ensures that the story remains interesting and captivating, but it also makes it possible for the characters to undergo substantial growth and development.

c. Remarkable storyline twists and cliffhangers: The show is well-known for its stunning plot twists and cliffhangers, which keep viewers on the edge of their seats and engrossed in the story. These unexpected occurrences frequently involve the downfall of significant personalities, as well as surprising alliances and betrayals.

The Aspects of the Visual and Technical
The popularity of Game of Thrones can be attributed in large part to the show's visually gorgeous and technically advanced production work, both of which have garnered widespread praise. There are a number of noteworthy aspects of the show's production, including the following:

a. Sets and locations: The series was shot in a number of different places, including Croatia, Iceland, and Northern Ireland, affording the producers the opportunity to film in a wide variety of breathtaking settings. In addition, the creators of the show developed magnificent sets, including as the well-known Red Keep and the Wall, which contributed to the immersive quality of the series.

b. Costumes and makeup: The departments of costume and makeup were extremely important in the process of bringing the land of Westeros to life. The attention to detail was astonishing, and it was evident in everything from the elaborate patterns of the Lannister emblem to the prosthetics that were used to make the White Walkers.

Special effects and cinematography: In order to produce its epic battle sequences and otherworldly monsters, Game of Thrones utilised cutting-edge special effects and cinematography techniques. The crew responsible for the show's visual effects was honoured with a number of prizes, including several Emmys, for their efforts.

Legacy and Influence on the World
Game of Thrones has left an indelible mark on the world of television, serving as a source of inspiration for a multitude of imitators and igniting a resurgence of interest in the fantasy storytelling genre. Among the most important legacies left behind by the show are the following:

In the first place, Game of Thrones was a breakthrough series that pushed the boundaries of what was possible on television. This series was responsible for changing the landscape of television. As a result of its intricate story structure, high production qualities, and mature subject matter, it set the way for later television programmes that were ambitious and demanding.

A renaissance of interest in the fantasy genre has been brought about as a result of the popularity of Game of Thrones, which has led to the production of a great number of books, television shows, and films in the genre's wake.

As a result of the show's influence on popular culture, words like as "Winter is coming" and "Valar Morghulis" have become ingrained in popular culture. The show's characters, themes, and iconic events have become engrained in popular culture.

Final Thoughts

The television landscape has been irrevocably altered as a result of the significant impact that the trailblazing series Game of Thrones has had. Its intricate storyline, unforgettable characters, and breathtaking images have enthralled viewers and inspired a great number of people to create their own versions of it. In light of the fact that we are contemplating the legacy of the show, it is quite evident that Game of Thrones will continue to be praised and studied for future years.

'''

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts([GOT])

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'of': 2,
#  'and': 3,
#  'a': 4,
#  'to': 5,
#  'in': 6,
#  'is': 7,
#  'as': 8,
#  'that': 9,
#  'game': 10,
#  'thrones': 11,
#  'who': 12,
#  'series': 13,
#  'on': 14,
#  'characters': 15,
#  'for': 16,
#  'are': 17,
#  'it': 18,
#  'their': 19,
#  'show': 20,
#  'has': 21,
#  'television': 22,
#  'which': 23,
#  'by': 24,
#  'this': 25,
#  'its': 26,
#  'her': 27,
#  'family': 28,
#  'number': 29,
#  'was': 30,
#  'world': 31,
#  'with': 32,
#  'people': 33,
#  'frequently': 34,
#  'have': 35,
#  "show's": 36,
#  'an': 37,
#  'including': 38,
#  'structure': 39,
#  'most': 40,
#  'following': 41,
#  'own': 42,
#  'result': 43,
#  'fact': 44,
#  'he': 45,
#  'popular': 46,
#  'character': 47,
#  'fantasy': 48,
#  'into': 49,
#  'narrative': 50,
#  'intricate': 51,
#  'power': 52,
#  'order': 53,
#  'moral': 54,
#  'between': 55,
#  'effects': 56,
#  'his': 57,
#  'throughout': 58,
#  'possible': 59,
#  'well': 60,
#  'story': 61,
#  'production': 62,
# ...

# %%
len(tokenizer.word_index)
# Out:
# 547

# %%
for sentence in GOT.split('. '):
    print(sentence)
# Out:
# In the beginning
#
# A television series that is based on the novel series "A Song of Ice and Fire" written by George R.R
# Martin, "Game of Thrones" is an epic fantasy television broadcast
# The show, which made its debut on HBO in 2011, soon garnered a big fanbase and received critical acclaim because to the detailed plot, fascinating characters, and spectacular cinematography that it included
# Over the course of eight seasons and 73 episodes, the series became a cultural phenomenon and left an indelible mark on the world of television
# For the purpose of providing a full study of this ground-breaking series, we will look into a variety of facets of the programme, including its themes, characters, and narrative structure, in this blog post.
#
#
# Recurring Ideas and Symbolism
# The storyline of Game of Thrones is intricate, and over its duration, it delves into a wide range of topics and represents a variety of symbols
# ...

# %%
for sentence in GOT.split('. '):
    print(tokenizer.texts_to_sequences([sentence])[0])
# Out:
# [6, 1, 176, 4, 22, 13, 9, 7, 177, 14, 1, 178, 13, 4, 179, 2, 180, 3, 181, 182, 24, 183, 98, 98]
# [184, 10, 2, 11, 7, 37, 99, 48, 22, 185]
# [1, 20, 23, 186, 26, 187, 14, 188, 6, 189, 190, 100, 4, 191, 192, 3, 193, 194, 195, 63, 5, 1, 196, 64, 197, 15, 3, 198, 65, 9, 18, 101]
# [66, 1, 67, 2, 199, 102, 3, 200, 201, 1, 13, 202, 4, 203, 204, 3, 68, 37, 103, 104, 14, 1, 31, 2, 22]
# [16, 1, 205, 2, 206, 4, 207, 208, 2, 25, 209, 210, 13, 105, 69, 211, 49, 4, 70, 2, 212, 2, 1, 106, 38, 26, 71, 15, 3, 50, 39, 6, 25, 213, 214, 215, 107, 3, 216, 1, 72, 2, 10, 2, 11, 7, 51, 3, 66, 26, 217, 18, 108, 49, 4, 73, 218, 2, 109, 3, 219, 4, 70, 2, 220]
# [101, 74, 1, 40, 75, 71, 17, 1, 41, 4]
# [52, 3, 1, 221, 76, 18, 21, 1, 13, 7, 222, 32, 110, 2, 33, 12, 223, 52, 111, 224, 225, 77, 226, 1, 227, 2, 19, 112]
# [25, 78, 7, 228, 24, 15, 79, 8, 229, 80, 3, 230, 12, 231, 1, 232, 233, 2, 234, 3, 1, 235, 9, 33, 69, 236, 5, 6, 53, 5, 237, 52, 113]
# ...

# %%
input_sequences = []

for sentence in GOT.split('. '):
    token_list = tokenizer.texts_to_sequences([sentence])[0]

    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i+1]
        input_sequences.append(n_gram_sequence)

print(input_sequences)
# Out:
# [[6, 1], [6, 1, 176], [6, 1, 176, 4], [6, 1, 176, 4, 22], [6, 1, 176, 4, 22, 13], [6, 1, 176, 4, 22, 13, 9], [6, 1, 176, 4, 22, 13, 9, 7], [6, 1, 176, 4, 22, 13, 9, 7, 177], [6, 1, 176, 4, 22, 13, 9, 7, 177, 14], [6, 1, 176, 4, 22, 13, 9, 7, 177, 14, 1], [6, 1, 176, 4, 22, 13, 9, 7, 177, 14, 1, 178], [6, 1, 176, 4, 22, 13, 9, 7, 177, 14, 1, 178, 13], [6, 1, 176, 4, 22, 13, 9, 7, 177, 14, 1, 178, 13, 4], [6, 1, 176, 4, 22, 13, 9, 7, 177, 14, 1, 178, 13, 4, 179], [6, 1, 176, 4, 22, 13, 9, 7, 177, 14, 1, 178, 13, 4, 179, 2], [6, 1, 176, 4, 22, 13, 9, 7, 177, 14, 1, 178, 13, 4, 179, 2, 180], [6, 1, 176, 4, 22, 13, 9, 7, 177, 14, 1, 178, 13, 4, 179, 2, 180, 3], [6, 1, 176, 4, 22, 13, 9, 7, 177, 14, 1, 178, 13, 4, 179, 2, 180, 3, 181], [6, 1, 176, 4, 22, 13, 9, 7, 177, 14, 1, 178, 13, 4, 179, 2, 180, 3, 181, 182], [6, 1, 176, 4, 22, 13, 9, 7, 177, 14, 1, 178, 13, 4, 179, 2, 180, 3, 181, 182, 24], [6, 1, 176, 4, 22, 13, 9, 7, 177, 14, 1, 178, 13, 4, 179, 2, 180, 3, 181, 182, 24, 183], [6, 1
# ...

# %%
max_len = max([len(x) for x in input_sequences])

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input_sequences = pad_sequences(input_sequences, maxlen=max_len, padding='pre')

# %%
X = padded_input_sequences[:, :-1]

# %%
Y = padded_input_sequences[:, -1]

# %%
X.shape
# Out:
# (1411, 94)

# %%
Y.shape
# Out:
# (1411,)

# %%
from tensorflow.keras.utils import to_categorical
Y = to_categorical(Y, num_classes=len(tokenizer.word_index)+1)

# %%
Y.shape
# Out:
# (1411, 548)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# %%
model = Sequential()
model.add(Embedding(input_dim=len(tokenizer.word_index)+1, output_dim=100, input_length=max_len-1))
model.add(LSTM(units=128))
model.add(Dense(548, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_1 (Embedding)     (None, 94, 100)           54800
#
#  lstm_1 (LSTM)               (None, 128)               117248
#
#  dense_1 (Dense)             (None, 548)               70692
#
# ...
# Total params: 242740 (948.20 KB)
# Trainable params: 242740 (948.20 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(X, Y, epochs=100)
# Out:
# Epoch 1/100
# 45/45 [==============================] - 10s 164ms/step - loss: 5.9762 - accuracy: 0.0645
# Epoch 2/100
# 45/45 [==============================] - 6s 128ms/step - loss: 5.4645 - accuracy: 0.0758
# Epoch 3/100
# 45/45 [==============================] - 7s 165ms/step - loss: 5.3732 - accuracy: 0.0801
# Epoch 4/100
# 45/45 [==============================] - 6s 128ms/step - loss: 5.2882 - accuracy: 0.0999
# Epoch 5/100
# 45/45 [==============================] - 7s 160ms/step - loss: 5.1789 - accuracy: 0.1219
# Epoch 6/100
# 45/45 [==============================] - 6s 127ms/step - loss: 5.0633 - accuracy: 0.1240
# Epoch 7/100
# 45/45 [==============================] - 7s 160ms/step - loss: 4.9616 - accuracy: 0.1332
# Epoch 8/100
# 45/45 [==============================] - 6s 130ms/step - loss: 4.8499 - accuracy: 0.1382
# Epoch 9/100
# 45/45 [==============================] - 7s 153ms/step - loss: 4.7254 - accuracy: 0.1609
# Epoch 10/100
# ...

# %%
import numpy as np


text = "The road he has taken is characterised"

for i in range(15):

  token_text = tokenizer.texts_to_sequences([text])[0]
  padded_token_text = pad_sequences([token_text], maxlen=max_len-1, padding='pre')
  position = np.argmax(model.predict(padded_token_text))


  for word, index in tokenizer.word_index.items():
        if index == position:
            text = text + " " + word
            print(text)
# Out:
# 1/1 [==============================] - 0s 37ms/step
# The road he has taken is characterised by
# 1/1 [==============================] - 0s 33ms/step
# The road he has taken is characterised by selflessness
# 1/1 [==============================] - 0s 35ms/step
# The road he has taken is characterised by selflessness and
# 1/1 [==============================] - 0s 33ms/step
# The road he has taken is characterised by selflessness and sacrifice
# 1/1 [==============================] - 0s 34ms/step
# The road he has taken is characterised by selflessness and sacrifice as
# 1/1 [==============================] - 0s 30ms/step
# The road he has taken is characterised by selflessness and sacrifice as he
# 1/1 [==============================] - 0s 33ms/step
# The road he has taken is characterised by selflessness and sacrifice as he always
# 1/1 [==============================] - 0s 32ms/step
# The road he has taken is characterised by selflessness and sacrifice as he always prioritises
# ...

# %%
# Out:
# 1/1 [==============================] - 0s 33ms/step
# the
